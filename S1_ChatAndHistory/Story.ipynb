# %%
# importing the necessary libraries and files
import os
import configparser

# setting up the configurations
config = configparser.ConfigParser()
config.read('../config.ini')
groq = config['groq']
cohere = config['cohere']

# Giving the api key
os.environ['GROQ_API_KEY'] = groq.get('GROQ_API_KEY')
os.environ['COHERE_API_KEY'] = cohere.get('COHERE_API_KEY')

# %%
import random_generators

from langchain_groq import ChatGroq
from langchain_cohere import ChatCohere

from langchain_core.messages import HumanMessage

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

parser = StrOutputParser()
    

actor=random_generators.actor_picker()
location=random_generators.location_picker()
theme=random_generators.theme_picker()


system_template = "You are a story writer.You are given the name of the actor, the location of the story and the theme or gener of the story." 
User_template = f'Generate a story with actor {actor} at location {location} and the of the story should be related to {theme}'

prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", system_template),
        ("user", User_template)
    ]
)



print(f"Actor: {actor}\nLocation: {location}\nTheme: {theme}")

## code for cohere.
print("\n*****ChatCohere LLM Response*****\n")
model_Cohere = ChatCohere(model="command-r-plus")
chain_Cohere = prompt_template | model_Cohere | parser
print(chain_Cohere.invoke({actor:actor,location:location,theme:theme}))



## Code for Groq
print("\n*****ChatGroq LLM Response*****\n")
model_Groq = ChatGroq(model="llama3-8b-8192")
chain_Groq = prompt_template | model_Groq
print(chain_Groq.invoke({actor:actor,location:location,theme:theme}))
# Out:
# Actor: Chris Evens
# Location: Brooklyn
# Theme: Romance
#
# *****ChatCohere LLM Response*****
#
# Title: Brooklyn Romance
#
# Chris Evans, a renowned actor, found himself in the vibrant borough of Brooklyn, New York, for a film shoot. As he spent time in the eclectic neighborhood, he couldn't help but feel a sense of charm and warmth that seemed to permeate the air. It was during one of his strolls through Prospect Park that he noticed her.
#
# Her name was Emily, a local artist with a passion for painting. She often set up her easel in the park, capturing the vibrant autumn colors and the gentle breeze that rustled the remaining leaves. Chris was immediately drawn to her talent and the way she immersed herself in her art, seemingly oblivious to the world around her.
#
# As fate would have it, Chris and Emily crossed paths at a local café. He approached her, intrigued by her unique aura. They struck up a conversation, and Chris learned about her passion for art and her deep connection to Brooklyn. There was an instant spark between them—an unspoken attraction that neither could deny.
#
# Chris invited Emily to explore Brooklyn with him. They wandered through the streets, discovering hidden gems and local hotspots. They shared stories of their lives, dreams, and passions. Chris was captivated by Emily's free-spirited nature and her unwavering love for her hometown.
#
# As they spent more time together, their bond deepened. They strolled along the Brooklyn Heights Promenade, taking in the breathtaking views of the Manhattan skyline. They visited the Brooklyn Botanic Garden, where they picnicked among the vibrant flowers and lush greenery. Every moment they shared was filled with laughter, deep conversations, and a growing intimacy.
#
# However, Chris's time in Brooklyn was limited. As the film shoot drew to a close, he faced a difficult decision. He had fallen deeply in love with Emily and the life they had begun to build together in Brooklyn. He knew that returning to his usual life of red carpets and premieres would mean leaving a piece of his heart behind.
#
# On his last night in Brooklyn, Chris and Emily shared a heartfelt conversation under the stars on the rooftop of her apartment building. They spoke of their love and the future that lay ahead. Chris knew he couldn't let her go, and Emily felt the same. They made a promise to each other—a promise to find a way to make their love work despite the distance and the challenges of their respective careers.
#
# As Chris departed Brooklyn, he carried with him the memories of the romantic adventures he had shared with Emily. They maintained their connection through frequent phone calls, heartfelt letters, and visits whenever their schedules allowed. Their love became a beacon, guiding them through the highs and lows of their lives.
#
# In the end, Chris and Emily's love story became a testament to the power of romance in Brooklyn. It was a love that transcended distances and careers, a love that flourished in the heart of a vibrant borough. And whenever Chris returned to Brooklyn, he was reminded of the beauty that can be found in unexpected places and the power of a love that can bridge any distance.
#
# *****ChatGroq LLM Response*****
#
# content="Here's a story:\n\nTitle: Love in the Borough\n\nChris Evans stars as Max Wellington, a successful advertising executive who has it all: a thriving career, a stunning apartment in Brooklyn's trendy Williamsburg neighborhood, and a string of shallow relationships. But despite his outward success, Max feels unfulfilled and restless, like something is missing from his life.\n\nThat all changes when he meets Sophie, a free-spirited artist who runs a charming vintage clothing shop in the heart of Brooklyn's Bushwick neighborhood. Sophie is everything Max is not: creative, spontaneous, and passionate. The two meet by chance at a local coffee shop, where Sophie is painting a mural on the wall, and Max is immediately smitten.\n\nAs they start to spend more time together, Max finds himself falling deeply in love with Sophie's quirky charm and infectious enthusiasm. But their relationship is put to the test when Max's high-stress job demands his attention, and Sophie's artistic career takes off, leaving her little time for their blossoming romance.\n\nAs the days turn into weeks, Max and Sophie must confront their own fears and doubts about commitment, trust, and the future. Will they be able to find a way to make their love work, or will the demands of their busy lives tear them apart?\n\nAs the sun sets over the Brooklyn Bridge, Max and Sophie find themselves lost in the winding streets of DUMBO, hand in hand, laughing and talking about their dreams and aspirations. It's a moment of pure magic, and they both know that they have found something special.\n\nThe story is a romantic comedy-drama that explores the ups and downs of love and relationships in the vibrant and eclectic neighborhood of Brooklyn. With its rich cultural heritage, stunning architecture, and trendy vibe, Brooklyn provides the perfect backdrop for Max and Sophie's love story.\n\nThemes: Romance, comedy, relationships, self-discovery, love\n\nLocations: Williamsburg, Bushwick, DUMBO, Brooklyn Bridge, Brooklyn neighborhoods\n\nCharacter traits: Max - successful, charming, but also shallow and restless; Sophie - free-spirited, artistic, passionate, and quirky\n\nGenre: Romantic comedy-drama" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 436, 'prompt_tokens': 64, 'total_tokens': 500, 'completion_time': 0.363333333, 'prompt_time': 0.007841415, 'queue_time': 0.011337554000000001, 'total_time': 0.371174748}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae', 'finish_reason': 'stop', 'logprobs': None} id='run-86f6015f-1ff4-4265-94d3-52c39a3d66ec-0' usage_metadata={'input_tokens': 64, 'output_tokens': 436, 'total_tokens': 500}

# %%
from langchain_core.chat_history import (
    BaseChatMessageHistory,
    InMemoryChatMessageHistory,
)
from langchain_core.runnables.history import RunnableWithMessageHistory

store = {}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store: 
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]


config = {'configurable': {"session_id": "first"}}


# print(config['configurable']['session_id'])
model_Cohere = ChatCohere(model="command-r-plus")
model_Groq = ChatGroq(model="llama3-8b-8192")


not_quit=True
counter=0
while not_quit:
    if counter!=0:
        user=input('Please enter your suggestions to change the story.')
        User_template = "Change the given story according to user input." + user

        print("Changes are: ",user)
    else:
        actor=random_generators.actor_picker()
        location=random_generators.location_picker()
        theme=random_generators.theme_picker()

        print(f"Actor: {actor}\nLocation: {location}\nTheme: {theme}")


        User_template = f'You are a story writer.You are given the name of the actor, the location of the story and the theme or gener of the story.Generate a story with actor {actor} at location {location} and the of the story should be related to {theme}'

    withHistory = RunnableWithMessageHistory(model_Cohere, get_session_history)
    response = withHistory.invoke([HumanMessage(content=User_template)], config=config)
    print(response.content)

    withHistory = RunnableWithMessageHistory(model_Groq, get_session_history)
    response = withHistory.invoke([HumanMessage(content=User_template)], config=config)
    print(response.content)

    print('\nDo You wish to modify the story ? (y/n)')
    another=input('Do You wish to modify the story ? (y/n)')
    if another == 'n':
        not_quit=False
    counter+=1
# Out:
# Actor: Stan Lee
# Location: India
# Theme: Science Fiction
# Once upon a time, renowned comic book writer and publisher Stan Lee found himself transported to the vibrant and mystical land of India. As he wandered through the bustling streets of Mumbai, he couldn't help but notice the rich culture and heritage that surrounded him. The vibrant colors, the aromatic spices, and the sounds of bustling markets and lively Bollywood music filled his senses. But little did he know that his presence in India would soon become part of an extraordinary science fiction adventure.
#
# As Stan explored the city, he stumbled upon an ancient temple hidden away from the busy streets. Intrigued, he stepped inside and found himself in a mystical sanctuary adorned with intricate carvings and statues of Hindu gods and goddesses. Suddenly, a beam of otherworldly light descended upon him, and a mysterious voice echoed through the temple.
#
# "Greetings, Stan Lee," the voice boomed. "You have been chosen for a cosmic mission that will forever change the destiny of this planet."
#
# Before Stan could react, a group of futuristic beings appeared before him. They introduced themselves as the Guardians of the Cosmic Balance, tasked with maintaining order and harmony in the multiverse. They explained that India, with its deep spiritual roots and ancient wisdom, held a unique place in the cosmic order.
#
# "A powerful entity, known as the Chaos Bringer, threatens to upset the delicate balance of this universe," they explained. "Your creativity and imagination, Stan Lee, are renowned throughout the multiverse. We seek your help to create a team of extraordinary individuals who can stand against this impending threat."
#
# Stan Lee, always up for a thrilling adventure, accepted the challenge without hesitation. With the guidance of the Guardians, he embarked on a journey across India, seeking out individuals with exceptional abilities and a strong sense of justice.
#
# He ventured to the snowy peaks of the Himalayas, where he encountered a young monk with telekinetic powers. In the bustling city of Delhi, he found a tech-savvy genius who could control and manipulate technology with her mind. From the sacred Ganges River emerged a powerful hydrokinetic, able to control and shape water at will. And in the heart of the Thar Desert, Stan discovered a mysterious figure shrouded in sand, capable of incredible earth manipulation.
#
# As Stan assembled this diverse team, he named them the "Cosmic Crusaders," a force for good that would protect not just India but the entire multiverse from the impending chaos. Together, they trained, honed their powers, and prepared for the inevitable confrontation with the Chaos Bringer.
#
# The final battle took place amidst the majestic ruins of an ancient fort in Rajasthan. The Cosmic Crusaders, each bringing their unique abilities to bear, faced off against the Chaos Bringer and his minions. It was a battle of epic proportions, with the very fabric of reality hanging in the balance.
#
# Stan Lee, ever the master storyteller, played a pivotal role in the battle, using his creative powers to devise strategies and counter the Chaos Bringer's attacks. The Guardians of the Cosmic Balance lent their support, ensuring the battle did not spill over and cause collateral damage.
